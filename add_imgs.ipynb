# %%
import pandas as pd
from pyinaturalist import get_observations
import time
import os
import shutil
from datetime import datetime

def agregar_imagenes_a_csv(archivo_csv, fila_inicio=0, hacer_backup=True):
    """
    Añade la columna 'imagen' a un CSV con observaciones de iNaturalist
    
    Args:
        archivo_csv (str): Ruta al archivo CSV de entrada y salida
        fila_inicio (int): Número de fila desde donde comenzar el procesamiento
        hacer_backup (bool): Si es True, crea una copia de seguridad del archivo original
    """
    
    # Crear backup si se solicita
    if hacer_backup:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        backup_file = f"{archivo_csv}.backup_{timestamp}"
        shutil.copy2(archivo_csv, backup_file)
        print(f"Backup creado en: {backup_file}")
    
    try:
        df = pd.read_csv(archivo_csv)
        print(f"CSV cargado: {len(df)} filas encontradas")
    except Exception as e:
        print(f"Error al cargar el CSV: {e}")
        return
    
    if 'imagen' not in df.columns:
        df['imagen'] = None
        print("Columna 'imagen' añadida al DataFrame")
    
    print(f"Comenzando procesamiento desde la fila {fila_inicio}")
    
    for index, row in df.iterrows():
        # Saltar filas hasta llegar a la fila de inicio
        if index < fila_inicio:
            continue
            
        if pd.notna(row.get('imagen')) and row['imagen'] != '':
            print(f"Fila {index}: Ya tiene imagen, saltando...")
            continue
        
        observacion_id = row['id']
        print(f"Procesando fila {index}: ID {observacion_id}")
        
        try:
            response = get_observations(id=observacion_id)
            
            if response['results']:
                observation = response['results'][0]
                
                if observation['photos']:
                    photo_url = observation['photos'][0]['url'].replace('square', 'medium')
                    df.at[index, 'imagen'] = photo_url
                    print(f"  ✓ Imagen encontrada: {photo_url}")
                else:
                    df.at[index, 'imagen'] = 'Sin imagen'
                    print(f"  ✗ Observación sin imágenes")
            else:
                df.at[index, 'imagen'] = 'No encontrada'
                print(f"  ✗ Observación no encontrada")
                
        except Exception as e:
            df.at[index, 'imagen'] = f"Error: {str(e)}"
            print(f"  ! Error al procesar: {e}")
        
        df.to_csv(archivo_csv, index=False)
        print(f"  → Progreso guardado en {archivo_csv}")
        time.sleep(1)
    
    print(f"\nProceso completado! Archivo actualizado en: {archivo_csv}")
    return df

# Uso del código
if __name__ == "__main__":
    archivo_entrada = "ubicaciones.csv"
    
    # Preguntar al usuario desde qué fila quiere empezar
    try:
        fila_inicio = 5002
    except ValueError:
        print("Entrada no válida, comenzando desde la fila 0")
        fila_inicio = 0
    
    # Ejecutar el proceso
    df_resultado = agregar_imagenes_a_csv(archivo_entrada, fila_inicio=fila_inicio, hacer_backup=True)
    
    # Mostrar resumen
    if df_resultado is not None:
        print("\nResumen final:")
        print(f"Total de filas procesadas: {len(df_resultado)}")
        print("Distribución de estados:")
        print(df_resultado['imagen'].value_counts())
# Out:
# Backup creado en: ubicaciones.csv.backup_20251129_180535
# CSV cargado: 9999 filas encontradas
# Columna 'imagen' añadida al DataFrame
# Procesando fila 0: ID 274076247
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/492787363/medium.jpeg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 1: ID 290035743
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/521715680/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 2: ID 314934926
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/568874088/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 3: ID 315164886
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/569320745/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 4: ID 324187710
#   ✓ Imagen encontrada: https://static.inaturalist.org/photos/586719919/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 
medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 267: ID 300044870
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/540590403/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 268: ID 318827427
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/576263426/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 269: ID 324248982
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/586841785/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 270: ID 268974663
#   ✓ Imagen encontrada: https://static.inaturalist.org/photos/483547718/medium.jpeg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 271: ID 283747476
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/509869236/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 272: ID 296896948
#   ✓ Imagen encontrada: https://static.inaturalist.org/photos/534646583/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 273: ID 304301167
#   ✓ Imagen encontrada: https://static.inaturalist.org/photos/548551809/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 274: ID 305789832
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/551385521/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 275: ID 281891715
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/506411342/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 276: ID 287607716
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/517145930/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 277: ID 310292069
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/559999446/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 278: ID 324975731
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/588300861/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 279: ID 327884898
#   ✓ Imagen encontrada: https://static.inaturalist.org/photos/594073343/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 280: ID 280622262
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/504024159/medium.jpeg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 281: ID 283085238
#   ✓ Imagen encontrada: https://inaturalist-open-data.s3.amazonaws.com/photos/508644586/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 282: ID 291617028
#   ✓ Imagen encontrada: https://static.inaturalist.org/photos/524690847/medium.jpg
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 283: ID 321501172
# ...
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5856: ID 315944268
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=315944268
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5857: ID 319252744
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=319252744
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5858: ID 319595928
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=319595928
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5859: ID 326350180
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=326350180
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5860: ID 291572605
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=291572605
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5861: ID 291939514
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=291939514
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5862: ID 292459453
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=292459453
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5863: ID 318330537
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=318330537
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5864: ID 324622992
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=324622992
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5865: ID 272570423
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=272570423
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5866: ID 294237181
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=294237181
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5867: ID 296901756
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=296901756
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5868: ID 303623801
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=303623801
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5869: ID 322815550
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=322815550
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5870: ID 286092226
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=286092226
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5871: ID 301088771
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=301088771
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5872: ID 309418327
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=309418327
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5873: ID 318777991
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=318777991
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5874: ID 324975729
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=324975729
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5875: ID 273653707
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=273653707
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5876: ID 284972486
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=284972486
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5877: ID 295393220
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=295393220
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5878: ID 302456752
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=302456752
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5879: ID 327390183
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=327390183
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5880: ID 271335314
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=271335314
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5881: ID 297485551
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=297485551
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5882: ID 309118502
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=309118502
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5883: ID 309344811
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=309344811
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5884: ID 327985681
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=327985681
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5885: ID 292991878
#   ! Error al procesar: 429 Client Error: normal_throttling for url: https://api.inaturalist.org/v1/observations?id=292991878
#   → Progreso guardado en ubicaciones.csv
# Procesando fila 5886: ID 294461899
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 75
#      73 if __name__ == "__main__":
#      74     archivo_entrada = "ubicaciones.csv"
# ---> 75     df_resultado = agregar_imagenes_a_csv(archivo_entrada, hacer_backup=True)
#      77     if df_resultado is not None:
#      78         print("\nResumen final:")
#
# Cell In[2], line 45, in agregar_imagenes_a_csv(archivo_csv, hacer_backup)
#      42 print(f"Procesando fila {index}: ID {observacion_id}")
#      44 try:
# ---> 45     response = get_observations(id=observacion_id)
#      47     if response['results']:
#      48         observation = response['results'][0]
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyinaturalist/docs/forge.py:803, in Revision.__call__.<locals>.inner(*args, **kwargs)
#     799 @functools.wraps(callable)
#     800 def inner(*args, **kwargs):
#     801     # pylint: disable=E1102, not-callable
#     802     mapped = inner.__mapper__(*args, **kwargs)
# --> 803     return callable(*mapped.args, **mapped.kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyinaturalist/v1/observations.py:91, in get_observations(**params)
#      89     observations = paginate_all(get, f'{API_V1}/observations', method='id', **params)
#      90 else:
# ---> 91     observations = get(f'{API_V1}/observations', **params).json()
#      93 observations['results'] = convert_all_coordinates(observations['results'])
#      94 observations['results'] = convert_all_timestamps(observations['results'])
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyinaturalist/session.py:426, in get(url, session, **kwargs)
#     424 """Wrapper around :py:func:`requests.get` with additional options specific to iNat API requests"""
#     425 session = session or get_local_session()
# --> 426 return session.request('GET', url, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyinaturalist/session.py:273, in ClientSession.request(self, method, url, headers, json, access_token, allow_redirects, allow_str_ids, dry_run, expire_after, files, ids, only_if_cached, raise_for_status, refresh, stream, timeout, verify, **params)
#     237 """Wrapper around :py:func:`requests.request` with additional options specific to iNat API requests
#     238
#     239 Args:
#    (...)
#     259     API response
#     260 """
#     261 request = self.prepare_inat_request(
#     262     method=method,
#     263     url=url,
#    (...)
#     270     params=params,
#     271 )
# --> 273 response = self.send(
#     274     request,
#     275     dry_run=dry_run,
#     276     expire_after=expire_after,
#     277     only_if_cached=only_if_cached,
#     278     refresh=refresh,
#     279     timeout=timeout,
#     280     allow_redirects=allow_redirects,
#     281     stream=stream,
#     282     verify=verify,
#     283 )
#     285 # Raise an exception if the request failed (after retries are exceeded)
#     286 if raise_for_status:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyinaturalist/session.py:322, in ClientSession.send(self, request, dry_run, expire_after, refresh, retries, timeout, **kwargs)
#     320 # Otherwise, send the request
#     321 read_timeout = timeout or self.timeout
# --> 322 response = super().send(
#     323     request,
#     324     expire_after=expire_after,
#     325     refresh=refresh,
#     326     timeout=(CONNECT_TIMEOUT, read_timeout),
#     327     **kwargs,
#     328 )
#     329 response = self._validate_json(
#     330     request,
#     331     response,
#    (...)
#     335     **kwargs,
#     336 )
#     338 logger.debug(format_response(response))
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/requests_cache/session.py:230, in CacheMixin.send(self, request, expire_after, only_if_cached, refresh, force_refresh, **kwargs)
#     228     response = self._resend(request, actions, cached_response, **kwargs)  # type: ignore
#     229 elif actions.send_request:
# --> 230     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#     231 else:
#     232     response = cached_response  # type: ignore  # Guaranteed to be non-None by this point
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/requests_cache/session.py:254, in CacheMixin._send_and_cache(self, request, actions, cached_response, **kwargs)
#     250 """Send a request and cache the response, unless disabled by settings or headers.
#     251 If applicable, also handle conditional requests.
#     252 """
#     253 request = actions.update_request(request)
# --> 254 response = super().send(request, **kwargs)
#     255 actions.update_from_response(response)
#     257 if not actions.skip_write:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/requests_ratelimiter/requests_ratelimiter.py:95, in LimiterMixin.send(self, request, **kwargs)
#      85 """Send a request with rate-limiting.
#      86
#      87 Raises:
#      88     :py:exc:`.BucketFullException` if this request would result in a delay longer than ``max_delay``
#      89 """
#      90 with self.limiter.ratelimit(
#      91     self._bucket_name(request),
#      92     delay=True,
#      93     max_delay=self.max_delay,
#      94 ):
# ---> 95     response = super().send(request, **kwargs)
#      96     if response.status_code in self.limit_statuses:
#      97         self._fill_bucket(request)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /srv/conda/envs/notebook/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /srv/conda/envs/notebook/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /srv/conda/envs/notebook/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /srv/conda/envs/notebook/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File /srv/conda/envs/notebook/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /srv/conda/envs/notebook/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
